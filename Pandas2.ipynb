# %%
import pandas as pd
df=pd.read_csv("dataset.csv")
df.head(5)
# Out:
#    S.N.                                   Traded Companies  \
# 0     1                        8.75 % Prime Debenture 2085
# 1     2  Aarambha Chautari Laghubitta Bittiya Sanstha L...
# 2     3       ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED
# 3     4              Agricultural Development Bank Limited
# 4     5                             Ajod Insurance Limited
#
#    No. Of Transaction  Max Price  Min Price  Closing Price  Traded Shares  \
# 0                   9      870.0      853.7          870.0            180
# 1                  10      849.9      822.1          844.9            123
# 2                   8      542.5      503.0          542.5             70
# 3                 274      330.0      319.2          321.0          28991
# 4                  39      472.0      455.0          460.0           1303
#
#       Amount  Previous Closing Difference Rs.  \
# 0   154645.5             853.5         16.50
# 1   103140.4             838.0          6.90
# ...

# %%
for index, row in df.iterrows():
    print(index,row)
# Out:
# 0 S.N.                                                             1
# Traded Companies                       8.75 % Prime Debenture 2085
# No. Of Transaction                                               9
# Max Price                                                    870.0
# Min Price                                                    853.7
# Closing Price                                                870.0
# Traded Shares                                                  180
# Amount                                                    154645.5
# Previous Closing                                             853.5
# Difference Rs.                                              16.50
# Unnamed: 10
# Name: 0, dtype: object
# 1 S.N.                                                                  2
# Traded Companies      Aarambha Chautari Laghubitta Bittiya Sanstha L...
# No. Of Transaction                                                   10
# ...

# %%
for index, row in df.iterrows():
    print(index,row["Traded Companies"])
# Out:
# 0 8.75 % Prime Debenture 2085
# 1 Aarambha Chautari Laghubitta Bittiya Sanstha Limited
# 2 ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED
# 3 Agricultural Development Bank Limited
# 4 Ajod Insurance Limited
# 5 Ankhu Khola Jalvidhyut Company Ltd
# 6 Api Power Company Ltd.
# 7 Arun Kabeli Power Ltd.
# 8 Arun Valley Hydropower Development Co. Ltd.
# 9 Asha Laghubitta Bittiya Sanstha Ltd
# 10 Asian Life Insurance Co. Limited
# 11 Balephi Hydropower Limited
# 12 Barun Hydropower Co. Ltd.
# 13 Best Finance Company Ltd.
# 14 Bishal Bazar Company Limited
# 15 Bottlers Nepal (Terai) Limited
# 16 Buddha Bhumi Nepal Hydropower Company Limited
# 17 Butwal Power Company Limited
# 18 CEDB Hydropower Development Company Limited
# 19 Central Finance Co. Ltd.
# 20 Century Commercial Bank Ltd.
# 21 Chandragiri Hills Limited
# 22 Chhimek Laghubitta Bittiya Sanstha Limited
# 23 Chhyangdi Hydropower Ltd.
# 24 Chilime Hydropower Company Limited
# 25 Citizen Bank International Limited
# ...

# %%
# filtering data

df.loc[df["No. Of Transaction"]==3]
# Out:
#     S.N.                Traded Companies  No. Of Transaction  Max Price  \
# 15    16  Bottlers Nepal (Terai) Limited                   3   12709.90
# 27    28         Citizens Mutual Fund -1                   3       8.67
#
#     Min Price  Closing Price  Traded Shares     Amount  Previous Closing  \
# 15   12700.00       12700.00             30  381099.00           12460.7
# 27       8.61           8.61           1725   14895.75               8.5
#
#    Difference Rs.                                   Unnamed: 10
# 15        239.30
# 27          0.11

# %%
df.describe()
# Out:
#             S.N.  No. Of Transaction    Max Price     Min Price  \
# count  40.000000           40.000000     40.00000     40.000000
# mean   20.500000          111.525000    963.47900    940.885750
# std    11.690452          131.645793   2023.80837   2021.773813
# min     1.000000            2.000000      8.67000      8.610000
# 25%    10.750000           21.250000    281.60000    266.775000
# 50%    20.500000           65.500000    448.00000    425.500000
# 75%    30.250000          129.250000    854.92500    830.000000
# max    40.000000          632.000000  12709.90000  12700.000000
#
#        Closing Price  Traded Shares        Amount  Previous Closing
# count      40.000000      40.000000  4.000000e+01         40.000000
# mean      953.882500   16296.750000  5.350951e+06        940.146250
# std      2021.248193   37808.532332  8.919244e+06       1983.521574
# min         8.610000      30.000000  1.476900e+04          8.500000
# ...

# %%
df=df.sort_values("Amount", ascending=False)
df.head(15)
# Out:
#     S.N.                                   Traded Companies  \
# 29    30                                     Civil Bank Ltd
# 7      8                             Arun Kabeli Power Ltd.
# 8      9        Arun Valley Hydropower Development Co. Ltd.
# 6      7                             Api Power Company Ltd.
# 26    27                           Citizen Investment Trust
# 22    23         Chhimek Laghubitta Bittiya Sanstha Limited
# 3      4              Agricultural Development Bank Limited
# 10    11                   Asian Life Insurance Co. Limited
# 20    21                       Century Commercial Bank Ltd.
# 12    13                          Barun Hydropower Co. Ltd.
# 24    25                 Chilime Hydropower Company Limited
# 38    39  Forward Microfinance Laghubitta Bittiya Sansth...
# 5      6                 Ankhu Khola Jalvidhyut Company Ltd
# 35    36                               Everest Bank Limited
# 25    26                 Citizen Bank International Limited
#
# ...

# %%
df=df.sort_values("Amount",ascending=True)
df.head(8)
# Out:
#     S.N.                                   Traded Companies  \
# 28    29                             CITIZENS MUTUAL FUND 2
# 27    28                            Citizens Mutual Fund -1
# 2      3       ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED
# 1      2  Aarambha Chautari Laghubitta Bittiya Sanstha L...
# 0      1                        8.75 % Prime Debenture 2085
# 16    17      Buddha Bhumi Nepal Hydropower Company Limited
# 15    16                     Bottlers Nepal (Terai) Limited
# 34    35                             Emerging Nepal Limited
#
#     No. Of Transaction  Max Price  Min Price  Closing Price  Traded Shares  \
# 28                   2       9.39       9.22           9.39           1600
# 27                   3       8.67       8.61           8.61           1725
# 2                    8     542.50     503.00         542.50             70
# 1                   10     849.90     822.10         844.90            123
# ...

# %%
df["Totals"]=df["No. Of Transaction"] + df["Max Price"] + df["Min Price"]
df.head(3)
# Out:
#     S.N.                              Traded Companies  No. Of Transaction  \
# 28    29                        CITIZENS MUTUAL FUND 2                   2
# 27    28                       Citizens Mutual Fund -1                   3
# 2      3  ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED                   8
#
#     Max Price  Min Price  Closing Price  Traded Shares    Amount  \
# 28       9.39       9.22           9.39           1600  14769.00
# 27       8.67       8.61           8.61           1725  14895.75
# 2      542.50     503.00         542.50             70  36964.90
#
#     Previous Closing Difference Rs.  \
# 28              9.25          0.14
# 27              8.50          0.11
# 2             493.20         49.30
#
#                                      Unnamed: 10   Totals
# 28                                                  20.61
# 27                                                  20.28
# 2                                                 1053.50

# %%
df.head(4)
# Out:
#     S.N.                                   Traded Companies  \
# 28    29                             CITIZENS MUTUAL FUND 2
# 27    28                            Citizens Mutual Fund -1
# 2      3       ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED
# 1      2  Aarambha Chautari Laghubitta Bittiya Sanstha L...
#
#     No. Of Transaction  Max Price  Min Price  Closing Price  Traded Shares  \
# 28                   2       9.39       9.22           9.39           1600
# 27                   3       8.67       8.61           8.61           1725
# 2                    8     542.50     503.00         542.50             70
# 1                   10     849.90     822.10         844.90            123
#
#        Amount  Previous Closing Difference Rs.  \
# 28   14769.00              9.25          0.14
# 27   14895.75              8.50          0.11
# 2    36964.90            493.20         49.30
# 1   103140.40            838.00          6.90
#
# ...

# %%
dff=df.drop(columns=["Totals"])
dff.head(2)
# Out:
#     S.N.         Traded Companies  No. Of Transaction  Max Price  Min Price  \
# 28    29   CITIZENS MUTUAL FUND 2                   2       9.39       9.22
# 27    28  Citizens Mutual Fund -1                   3       8.67       8.61
#
#     Closing Price  Traded Shares    Amount  Previous Closing Difference Rs.  \
# 28           9.39           1600  14769.00              9.25          0.14
# 27           8.61           1725  14895.75              8.50          0.11
#
#                                      Unnamed: 10
# 28
# 27

# %%
df=dff.drop(columns=["Unnamed: 10"])
df.head(2)
# Out:
#     S.N.         Traded Companies  No. Of Transaction  Max Price  Min Price  \
# 28    29   CITIZENS MUTUAL FUND 2                   2       9.39       9.22
# 27    28  Citizens Mutual Fund -1                   3       8.67       8.61
#
#     Closing Price  Traded Shares    Amount  Previous Closing Difference Rs.
# 28           9.39           1600  14769.00              9.25          0.14
# 27           8.61           1725  14895.75              8.50          0.11

# %%
df['Total']=df.iloc[:, 3:7].sum(axis=1)
df.head(4)
# Out:
#     S.N.                                   Traded Companies  \
# 28    29                             CITIZENS MUTUAL FUND 2
# 27    28                            Citizens Mutual Fund -1
# 2      3       ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED
# 1      2  Aarambha Chautari Laghubitta Bittiya Sanstha L...
#
#     No. Of Transaction  Max Price  Min Price  Closing Price  Traded Shares  \
# 28                   2       9.39       9.22           9.39           1600
# 27                   3       8.67       8.61           8.61           1725
# 2                    8     542.50     503.00         542.50             70
# 1                   10     849.90     822.10         844.90            123
#
#        Amount  Previous Closing Difference Rs.    Total
# 28   14769.00              9.25          0.14   1628.00
# 27   14895.75              8.50          0.11   1750.89
# 2    36964.90            493.20         49.30   1658.00
# 1   103140.40            838.00          6.90   2639.90

# %%
870+853.7+870+180
# Out:
# 2773.7

# %%
cols=list(df.columns)
df=df[cols[0:2] + [cols[-1]] + cols[2:10]]
df.head(3)
# Out:
#     S.N.                              Traded Companies    Total  \
# 28    29                        CITIZENS MUTUAL FUND 2  1628.00
# 27    28                       Citizens Mutual Fund -1  1750.89
# 2      3  ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED  1658.00
#
#     No. Of Transaction  Max Price  Min Price  Closing Price  Traded Shares  \
# 28                   2       9.39       9.22           9.39           1600
# 27                   3       8.67       8.61           8.61           1725
# 2                    8     542.50     503.00         542.50             70
#
#       Amount  Previous Closing Difference Rs.
# 28  14769.00              9.25          0.14
# 27  14895.75              8.50          0.11
# 2   36964.90            493.20         49.30

# %%
df.to_csv("advanced_pandas2_modified.csv",index=False)

# %%
# filtering data

df.loc[df["No. Of Transaction"]==3]
# Out:
#     S.N.                Traded Companies     Total  No. Of Transaction  \
# 27    28         Citizens Mutual Fund -1   1750.89                   3
# 15    16  Bottlers Nepal (Terai) Limited  38139.90                   3
#
#     Max Price  Min Price  Closing Price  Traded Shares     Amount  \
# 27       8.67       8.61           8.61           1725   14895.75
# 15   12709.90   12700.00       12700.00             30  381099.00
#
#     Previous Closing Difference Rs.
# 27               8.5          0.11
# 15           12460.7        239.30

# %%
df.loc[(df["No. Of Transaction"]==3) & (df["Max Price"]==200)]
# Out:
# Empty DataFrame
# Columns: [S.N., Traded Companies, Total, No. Of Transaction, Max Price, Min Price, Closing Price, Traded Shares, Amount, Previous Closing, Difference Rs.]
# Index: []

# %%
new_df=df.loc[df['Traded Companies'].str.contains("Bank")]
new_df
# Out:
#     S.N.                       Traded Companies     Total  No. Of Transaction  \
# 36    37            Excel Development Bank Ltd.    2827.9                  18
# 31    32     Corporate Development Bank Limited    7105.0                  67
# 25    26     Citizen Bank International Limited   18190.4                 119
# 35    36                   Everest Bank Limited   10285.2                  96
# 20    21           Century Commercial Bank Ltd.   44611.6                 248
# 3      4  Agricultural Development Bank Limited   29961.2                 274
# 29    30                         Civil Bank Ltd  227962.0                 315
#
#     Max Price  Min Price  Closing Price  Traded Shares      Amount  \
# 36      353.9      347.0          353.0           1774    618558.4
# 31      293.0      275.0          287.0           6250   1785434.7
# 25      220.0      213.7          217.7          17539   3812563.4
# 35      452.0      438.2          445.0           8950   3983396.0
# ...

# %%
new_df=df.loc[~df['Traded Companies'].str.contains("Bank")]
new_df
# Out:
#     S.N.                                   Traded Companies     Total  \
# 28    29                             CITIZENS MUTUAL FUND 2   1628.00
# 27    28                            Citizens Mutual Fund -1   1750.89
# 2      3       ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED   1658.00
# 1      2  Aarambha Chautari Laghubitta Bittiya Sanstha L...   2639.90
# 0      1                        8.75 % Prime Debenture 2085   2773.70
# 16    17      Buddha Bhumi Nepal Hydropower Company Limited   1968.00
# 15    16                     Bottlers Nepal (Terai) Limited  38139.90
# 34    35                             Emerging Nepal Limited   2576.10
# 30    31              Civil Laghubitta Bittiya Sanstha Ltd.   2879.00
# 39    40        Ganapati Laghubitta Bittiya Sanstha Limited   3371.80
# 14    15                       Bishal Bazar Company Limited  10720.00
# 4      5                             Ajod Insurance Limited   2690.00
# ...

# %%
import re
df.loc[df["Traded Companies"].str.contains('bank|limited',flags=re.I,regex=True)]
# Out:
#     S.N.                                   Traded Companies     Total  \
# 2      3       ADHIKHOLA LAGHUBITTA BITTIYA SANSTHA LIMITED    1658.0
# 1      2  Aarambha Chautari Laghubitta Bittiya Sanstha L...    2639.9
# 16    17      Buddha Bhumi Nepal Hydropower Company Limited    1968.0
# 15    16                     Bottlers Nepal (Terai) Limited   38139.9
# 34    35                             Emerging Nepal Limited    2576.1
# 39    40        Ganapati Laghubitta Bittiya Sanstha Limited    3371.8
# 14    15                       Bishal Bazar Company Limited   10720.0
# 4      5                             Ajod Insurance Limited    2690.0
# 36    37                        Excel Development Bank Ltd.    2827.9
# 17    18                       Butwal Power Company Limited    5373.0
# 32    33         Deprosc Laghubitta Bittiya Sanstha Limited    4626.0
# 31    32                 Corporate Development Bank Limited    7105.0
# ...

# %%
import re
df.loc[df["Traded Companies"].str.contains('^Ci[a-z]*',flags=re.I,regex=True)]
# Out:
#     S.N.                       Traded Companies      Total  \
# 28    29                 CITIZENS MUTUAL FUND 2    1628.00
# 27    28                Citizens Mutual Fund -1    1750.89
# 30    31  Civil Laghubitta Bittiya Sanstha Ltd.    2879.00
# 25    26     Citizen Bank International Limited   18190.40
# 26    27               Citizen Investment Trust   12869.90
# 29    30                         Civil Bank Ltd  227962.00
#
#     No. Of Transaction  Max Price  Min Price  Closing Price  Traded Shares  \
# 28                   2       9.39       9.22           9.39           1600
# 27                   3       8.67       8.61           8.61           1725
# 30                  15     754.00     731.00         745.00            649
# 25                 119     220.00     213.70         217.70          17539
# 26                 133    2339.00    2285.00        2318.90           5927
# 29                 315     211.00     202.00         209.00         227340
#
# ...
